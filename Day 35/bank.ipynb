# %%
import numpy as np
import pandas as pd

# %%
path = "../Data/bank.csv"
df = pd.read_csv(path, na_values='unknown')

# %%
df.sample(3)
# Out:
#      age         job  marital  education default  balance housing loan  \
# 899   56  technician  married  secondary      no      589     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# 899     NaN   23   oct       518         1    147         2  success     yes

# %%
df.nunique()
for col in df.columns:
    if df[col].nunique() < 5:
        print(f"{col}({df[col].nunique()}): {list(df[col].unique())}")
# Out:
# marital(3): ['married', 'single', 'divorced']
# education(3): ['secondary', 'tertiary', 'primary', nan]
# default(2): ['no', 'yes']
# housing(2): ['yes', 'no']
# loan(2): ['no', 'yes']
# contact(2): [nan, 'cellular', 'telephone']
# poutcome(3): [nan, 'other', 'failure', 'success']
# deposit(2): ['yes', 'no']

# %%
df.isnull().sum()
# Out:
# age             0
# job            70
# marital         0
# education     497
# default         0
# balance         0
# housing         0
# loan            0
# contact      2346
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome     8326
# deposit         0
# dtype: int64
